# %%
import pandas as pd

# %%
df = pd.read_csv('/home/mike-pi/Documents/coding/projects/disp/data/daily_cum.csv')

# %%
df
# Out:
#                0          1             2         3       4      5         6  \
# 0     СП Дудинка  1305/0800  7046N/08229E       NaN   070/7    нет   017/8.4
# 1      СП Диксон  2305/0800  6445N/04030E       NaN   270/3    0/0       NaN
# 2      СП Диксон  1405/0800  7042N/04555E       NaN   260/6  290/1  210/12,6
# 3      СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# 4      СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# 5      СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# 6      СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# 7      СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# 8            NaN        NaN           NaN       NaN     NaN    NaN       NaN
# 9      СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# 10     СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# ...

# %%
df.sort_values(by=['0', '1']).drop_duplicates()
# Out:
#                0          1             2         3       4      5         6  \
# 22  «СП Дудинка»  0106/0800  6458N/04000E       NaN     нет    нет       NaN
# 19  «СП Дудинка»  1805/0800  6458N/04000E       NaN  140/13  140/1       NaN
# 29  «СП Дудинка»  2505/0800  6458N/04000E       NaN   040/9  040/1       NaN
# 2      СП Диксон  1405/0800  7042N/04555E       NaN   260/6  290/1  210/12,6
# 3      СП Диксон  1710/0800           NaN  Мурманск     NaN    NaN       NaN
# 1      СП Диксон  2305/0800  6445N/04030E       NaN   270/3    0/0       NaN
# 0     СП Дудинка  1305/0800  7046N/08229E       NaN   070/7    нет   017/8.4
# 8            NaN        NaN           NaN       NaN     NaN    NaN       NaN
# 16           NaN        NaN           NaN       NaN     NaN    NaN       NaN
#
#        7    8                    9  ...  94  95  96  97  98  99  \
# 22   NaN  NaN                  NaN  ... NaN NaN NaN NaN NaN NaN
# 19   NaN  NaN                  NaN  ... NaN NaN NaN NaN NaN NaN
# ...

# %%
df.iloc[2, 103]
# Out:
# 'NNNN'
